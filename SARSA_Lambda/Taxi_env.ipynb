# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
env_name = "Taxi-v2"
epsilon = 1
decay_rate = 0.001
min_epsilon = 0.01
max_episodes = 3000
print_interval = 50
test_episodes = 2
lr = 0.2
gamma = 0.99
lam = 0.9

# %%
env = gym.make(env_name)
n_states = env.observation_space.n
n_actions = env.action_space.n
print(f"Number of states: {n_states}\n"
      f"Number of actions: {n_actions}")
# Out:
# Number of states: 500
# Number of actions: 6

# %%
q_table = np.random.uniform(size=(n_states, n_actions))
e_table = np.zeros((n_states, n_actions))

# %%
def choose_action(state):
    global q_table
    if epsilon > np.random.uniform():
        action = env.action_space.sample()
    else:
        action = np.argmax(q_table[state, :])
    return action

# %%
# def update_table(state, action, reward, done, next_state, next_action):
#     global q_table
#     q_table[state, action] += lr * (reward + gamma * q_table[next_state, next_action] * (1 - done) - q_table[state, action])

# %%
running_reward = []
for episode in range(1, 1 + max_episodes):
    state = env.reset()
    action = choose_action(state)
    done = False  
    episode_reward = 0
    while not done:
        next_state, reward, done, _ = env.step(action)
        next_action = choose_action(next_state)
#         update_table(state, action, reward, done, next_state, next_action)
        delta = reward + gamma * q_table[next_state, next_action] * (1 - done) - q_table[state, action]
        e_table[state, action] += 1
        
        q_table += lr * delta * e_table
        e_table = gamma * lam * e_table
        
        episode_reward += reward

        state = next_state
        action = next_action
            
    epsilon  = epsilon - decay_rate if epsilon - decay_rate > min_epsilon else min_epsilon
    
    if episode == 1:
        running_reward.append(episode_reward)
    else:
        running_reward.append(0.99 * running_reward[-1] + 0.01 * episode_reward)
    if episode % print_interval == 0:
        print(f"Ep:{episode}| "
              f"Ep_reward:{episode_reward}| "
              f"Running_reward:{running_reward[-1]:.3f}| "
             f"Epsilon:{epsilon:.3f}| ")
# Out:
# Ep:50| Ep_reward:-677| Running_reward:-781.471| Epsilon:0.950|
# Ep:100| Ep_reward:-668| Running_reward:-744.763| Epsilon:0.900|
# Ep:150| Ep_reward:-794| Running_reward:-728.387| Epsilon:0.850|
# Ep:200| Ep_reward:-695| Running_reward:-687.636| Epsilon:0.800|
# Ep:250| Ep_reward:-146| Running_reward:-638.005| Epsilon:0.750|
# Ep:300| Ep_reward:-513| Running_reward:-574.006| Epsilon:0.700|
# Ep:350| Ep_reward:-199| Running_reward:-472.774| Epsilon:0.650|
# Ep:400| Ep_reward:-81| Running_reward:-341.259| Epsilon:0.600|
# Ep:450| Ep_reward:-22| Running_reward:-254.936| Epsilon:0.550|
# Ep:500| Ep_reward:-9| Running_reward:-188.296| Epsilon:0.500|
# Ep:550| Ep_reward:-111| Running_reward:-137.992| Epsilon:0.450|
# Ep:600| Ep_reward:-74| Running_reward:-103.196| Epsilon:0.400|
# Ep:650| Ep_reward:-11| Running_reward:-72.806| Epsilon:0.350|
# Ep:700| Ep_reward:-19| Running_reward:-51.908| Epsilon:0.300|
# Ep:750| Ep_reward:12| Running_reward:-37.319| Epsilon:0.250|
# Ep:800| Ep_reward:-35| Running_reward:-25.868| Epsilon:0.200|
# Ep:850| Ep_reward:12| Running_reward:-19.204| Epsilon:0.150|
# Ep:900| Ep_reward:3| Running_reward:-11.850| Epsilon:0.100|
# Ep:950| Ep_reward:1| Running_reward:-8.846| Epsilon:0.050|
# Ep:1000| Ep_reward:-71| Running_reward:-7.490| Epsilon:0.010|
# Ep:1050| Ep_reward:5| Running_reward:-11.340| Epsilon:0.010|
# Ep:1100| Ep_reward:6| Running_reward:-6.578| Epsilon:0.010|
# Ep:1150| Ep_reward:10| Running_reward:-4.848| Epsilon:0.010|
# Ep:1200| Ep_reward:6| Running_reward:-4.769| Epsilon:0.010|
# Ep:1250| Ep_reward:7| Running_reward:-5.420| Epsilon:0.010|
# Ep:1300| Ep_reward:10| Running_reward:-10.630| Epsilon:0.010|
# Ep:1350| Ep_reward:9| Running_reward:-9.918| Epsilon:0.010|
# Ep:1400| Ep_reward:-51| Running_reward:-5.491| Epsilon:0.010|
# Ep:1450| Ep_reward:6| Running_reward:-6.855| Epsilon:0.010|
# Ep:1500| Ep_reward:8| Running_reward:-6.297| Epsilon:0.010|
# Ep:1550| Ep_reward:-15| Running_reward:-3.218| Epsilon:0.010|
# Ep:1600| Ep_reward:-100| Running_reward:-3.344| Epsilon:0.010|
# Ep:1650| Ep_reward:8| Running_reward:-4.891| Epsilon:0.010|
# Ep:1700| Ep_reward:10| Running_reward:-10.957| Epsilon:0.010|
# Ep:1750| Ep_reward:12| Running_reward:-6.720| Epsilon:0.010|
# Ep:1800| Ep_reward:9| Running_reward:-4.876| Epsilon:0.010|
# Ep:1850| Ep_reward:8| Running_reward:-2.999| Epsilon:0.010|
# Ep:1900| Ep_reward:6| Running_reward:-2.108| Epsilon:0.010|
# Ep:1950| Ep_reward:7| Running_reward:-0.450| Epsilon:0.010|
# Ep:2000| Ep_reward:9| Running_reward:0.481| Epsilon:0.010|
# Ep:2050| Ep_reward:4| Running_reward:0.453| Epsilon:0.010|
# Ep:2100| Ep_reward:8| Running_reward:0.440| Epsilon:0.010|
# Ep:2150| Ep_reward:13| Running_reward:1.440| Epsilon:0.010|
# Ep:2200| Ep_reward:4| Running_reward:3.031| Epsilon:0.010|
# Ep:2250| Ep_reward:-36| Running_reward:2.392| Epsilon:0.010|
# Ep:2300| Ep_reward:4| Running_reward:1.838| Epsilon:0.010|
# Ep:2350| Ep_reward:10| Running_reward:-1.006| Epsilon:0.010|
# Ep:2400| Ep_reward:7| Running_reward:1.993| Epsilon:0.010|
# Ep:2450| Ep_reward:8| Running_reward:3.629| Epsilon:0.010|
# Ep:2500| Ep_reward:9| Running_reward:2.080| Epsilon:0.010|
# Ep:2550| Ep_reward:1| Running_reward:0.210| Epsilon:0.010|
# Ep:2600| Ep_reward:10| Running_reward:0.879| Epsilon:0.010|
# Ep:2650| Ep_reward:13| Running_reward:2.433| Epsilon:0.010|
# Ep:2700| Ep_reward:9| Running_reward:2.878| Epsilon:0.010|
# Ep:2750| Ep_reward:2| Running_reward:3.012| Epsilon:0.010|
# Ep:2800| Ep_reward:-23| Running_reward:4.093| Epsilon:0.010|
# Ep:2850| Ep_reward:9| Running_reward:4.774| Epsilon:0.010|
# Ep:2900| Ep_reward:11| Running_reward:5.060| Epsilon:0.010|
# Ep:2950| Ep_reward:9| Running_reward:4.004| Epsilon:0.010|
# Ep:3000| Ep_reward:4| Running_reward:3.796| Epsilon:0.010|

# %%
plt.figure()
plt.style.use("ggplot")
plt.plot(np.arange(max_episodes), running_reward)
plt.title("Running_reward")
# Out:
# Text(0.5, 1.0, 'Running_reward')

# %%
for episode in range(1, 1 + test_episodes):
    state = env.reset()
    done = False  
    episode_reward = 0
    while not done:
        action = choose_action(state)
        next_state, reward, done, _ = env.step(action)
        env.render()
        episode_reward += reward
        state = next_state

    print(f"Ep:{episode}| "
          f"Ep_reward:{episode_reward}| ")
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | :_: : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R:_| : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:1| Ep_reward:5|
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | :_:G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: |_: :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : :_: : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | :_: : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R:_| : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:2| Ep_reward:9|

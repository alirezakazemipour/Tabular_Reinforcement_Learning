# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
env_name = "Taxi-v2"
epsilon = 1
decay_rate = 0.001
min_epsilon = 0.01
max_episodes = 2500
print_interval = 50
test_episodes = 2
lr = 0.4
gamma = 0.99

# %%
env = gym.make(env_name)
n_states = env.observation_space.n
n_actions = env.action_space.n
print(f"Number of states: {n_states}\n"
      f"Number of actions: {n_actions}")
# Out:
# Number of states: 500
# Number of actions: 6

# %%
q_table = np.zeros((n_states, n_actions))

# %%
def choose_action(state):
    global q_table
    if epsilon > np.random.uniform():
        action = env.action_space.sample()
    else:
        action = np.argmax(q_table[state, :])
    return action

# %%
def value(q_table, next_state, epsilon):
    optimal_q = np.max(q_table[next_state, :])
    return np.sum(np.multiply(epsilon / n_actions, q_table[next_state, :])) + (1 - epsilon) * optimal_q

# %%
def update_table(state, action, reward, done, v_next_state):
    global q_table
    q_table[state, action] += lr * (reward + gamma * v_next_state * (1 - done) - q_table[state, action])

# %%
running_reward = []
for episode in range(1, 1 + max_episodes):
    state = env.reset()
    done = False  
    episode_reward = 0
    while not done:
        action = choose_action(state)
        next_state, reward, done, _ = env.step(action)
        v_next_state = value(q_table, next_state, epsilon)
        update_table(state, action, reward, done, v_next_state)
        
        episode_reward += reward

        state = next_state
            
    epsilon  = epsilon - decay_rate if epsilon - decay_rate > min_epsilon else min_epsilon
    
    if episode == 1:
        running_reward.append(episode_reward)
    else:
        running_reward.append(0.99 * running_reward[-1] + 0.01 * episode_reward)
    if episode % print_interval == 0:
        print(f"Ep:{episode}| "
              f"Ep_reward:{episode_reward}| "
              f"Running_reward:{running_reward[-1]:.3f}| "
             f"Epsilon:{epsilon:.3f}| ")
# Out:
# Ep:50| Ep_reward:-677| Running_reward:-765.872| Epsilon:0.950|
# Ep:100| Ep_reward:-713| Running_reward:-727.299| Epsilon:0.900|
# Ep:150| Ep_reward:-659| Running_reward:-681.767| Epsilon:0.850|
# Ep:200| Ep_reward:-614| Running_reward:-622.319| Epsilon:0.800|
# Ep:250| Ep_reward:-229| Running_reward:-557.706| Epsilon:0.750|
# Ep:300| Ep_reward:-85| Running_reward:-468.707| Epsilon:0.700|
# Ep:350| Ep_reward:-78| Running_reward:-391.823| Epsilon:0.650|
# Ep:400| Ep_reward:-515| Running_reward:-323.158| Epsilon:0.600|
# Ep:450| Ep_reward:-301| Running_reward:-251.660| Epsilon:0.550|
# Ep:500| Ep_reward:-36| Running_reward:-200.383| Epsilon:0.500|
# Ep:550| Ep_reward:-144| Running_reward:-156.784| Epsilon:0.450|
# Ep:600| Ep_reward:-124| Running_reward:-117.281| Epsilon:0.400|
# Ep:650| Ep_reward:-10| Running_reward:-86.439| Epsilon:0.350|
# Ep:700| Ep_reward:-18| Running_reward:-62.165| Epsilon:0.300|
# Ep:750| Ep_reward:1| Running_reward:-45.138| Epsilon:0.250|
# Ep:800| Ep_reward:-27| Running_reward:-30.524| Epsilon:0.200|
# Ep:850| Ep_reward:2| Running_reward:-19.137| Epsilon:0.150|
# Ep:900| Ep_reward:-5| Running_reward:-11.445| Epsilon:0.100|
# Ep:950| Ep_reward:14| Running_reward:-6.179| Epsilon:0.050|
# Ep:1000| Ep_reward:2| Running_reward:-1.359| Epsilon:0.010|
# Ep:1050| Ep_reward:8| Running_reward:2.336| Epsilon:0.010|
# Ep:1100| Ep_reward:11| Running_reward:4.600| Epsilon:0.010|
# Ep:1150| Ep_reward:7| Running_reward:5.923| Epsilon:0.010|
# Ep:1200| Ep_reward:7| Running_reward:6.730| Epsilon:0.010|
# Ep:1250| Ep_reward:3| Running_reward:6.848| Epsilon:0.010|
# Ep:1300| Ep_reward:9| Running_reward:7.177| Epsilon:0.010|
# Ep:1350| Ep_reward:7| Running_reward:7.300| Epsilon:0.010|
# Ep:1400| Ep_reward:11| Running_reward:7.483| Epsilon:0.010|
# Ep:1450| Ep_reward:7| Running_reward:7.784| Epsilon:0.010|
# Ep:1500| Ep_reward:9| Running_reward:8.016| Epsilon:0.010|
# Ep:1550| Ep_reward:8| Running_reward:7.854| Epsilon:0.010|
# Ep:1600| Ep_reward:8| Running_reward:7.993| Epsilon:0.010|
# Ep:1650| Ep_reward:7| Running_reward:8.121| Epsilon:0.010|
# Ep:1700| Ep_reward:8| Running_reward:8.180| Epsilon:0.010|
# Ep:1750| Ep_reward:7| Running_reward:7.984| Epsilon:0.010|
# Ep:1800| Ep_reward:5| Running_reward:7.874| Epsilon:0.010|
# Ep:1850| Ep_reward:8| Running_reward:7.789| Epsilon:0.010|
# Ep:1900| Ep_reward:9| Running_reward:8.247| Epsilon:0.010|
# Ep:1950| Ep_reward:10| Running_reward:8.012| Epsilon:0.010|
# Ep:2000| Ep_reward:-3| Running_reward:7.759| Epsilon:0.010|
# Ep:2050| Ep_reward:8| Running_reward:8.096| Epsilon:0.010|
# Ep:2100| Ep_reward:10| Running_reward:7.814| Epsilon:0.010|
# Ep:2150| Ep_reward:11| Running_reward:7.763| Epsilon:0.010|
# Ep:2200| Ep_reward:7| Running_reward:8.207| Epsilon:0.010|
# Ep:2250| Ep_reward:-1| Running_reward:8.022| Epsilon:0.010|
# Ep:2300| Ep_reward:6| Running_reward:8.028| Epsilon:0.010|
# Ep:2350| Ep_reward:10| Running_reward:7.768| Epsilon:0.010|
# Ep:2400| Ep_reward:8| Running_reward:7.794| Epsilon:0.010|
# Ep:2450| Ep_reward:6| Running_reward:7.708| Epsilon:0.010|
# Ep:2500| Ep_reward:12| Running_reward:7.374| Epsilon:0.010|

# %%
plt.figure()
plt.style.use("ggplot")
plt.plot(np.arange(max_episodes), running_reward)
plt.title("Running_reward")
# Out:
# Text(0.5, 1.0, 'Running_reward')

# %%
for episode in range(1, 1 + test_episodes):
    state = env.reset()
    done = False  
    episode_reward = 0
    while not done:
        action = choose_action(state)
        next_state, reward, done, _ = env.step(action)
        env.render()
        episode_reward += reward
        state = next_state

    print(f"Ep:{episode}| "
          f"Ep_reward:{episode_reward}| ")
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:1| Ep_reward:7|
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : : : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : :_: : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | :_: : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R:_| : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:2| Ep_reward:9|

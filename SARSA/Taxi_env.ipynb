# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
env_name = "Taxi-v3"
epsilon = 1
decay_rate = 0.001
min_epsilon = 0.01
max_episodes = 2500
print_interval = 50
test_episodes = 2
lr = 0.4
gamma = 0.99

# %%
env = gym.make(env_name)
n_states = env.observation_space.n
n_actions = env.action_space.n
print(f"Number of states: {n_states}\n"
      f"Number of actions: {n_actions}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in spec(self, path)
#     131         try:
# --> 132             return self.env_specs[id]
#     133         except KeyError:
#
# KeyError: 'Taxi-v3'
#
# During handling of the above exception, another exception occurred:
#
# DeprecatedEnv                             Traceback (most recent call last)
# <ipython-input-3-ea7647f1e372> in <module>
# ----> 1 env = gym.make(env_name)
#       2 n_states = env.observation_space.n
#       3 n_actions = env.action_space.n
#       4 print(f"Number of states: {n_states}\n"
#       5       f"Number of actions: {n_actions}")
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in make(id, **kwargs)
#     154
#     155 def make(id, **kwargs):
# --> 156     return registry.make(id, **kwargs)
#     157
#     158 def spec(id):
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in make(self, path, **kwargs)
#      98         else:
#      99             logger.info('Making new env: %s', path)
# --> 100         spec = self.spec(path)
#     101         env = spec.make(**kwargs)
#     102         # We used to have people override _reset/_step rather than
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in spec(self, path)
#     138                              if env_name == valid_env_spec._env_name]
#     139             if matching_envs:
# --> 140                 raise error.DeprecatedEnv('Env {} not found (valid versions include {})'.format(id, matching_envs))
#     141             else:
#     142                 raise error.UnregisteredEnv('No registered env with id: {}'.format(id))
#
# DeprecatedEnv: Env Taxi-v3 not found (valid versions include ['Taxi-v2'])

# %%
q_table = np.zeros((n_states, n_actions))

# %%
def choose_action(state):
    global q_table
    if epsilon > np.random.uniform():
        action = env.action_space.sample()
    else:
        action = np.argmax(q_table[state, :])
    return action

# %%
def update_table(state, action, reward, done, next_state, next_action):
    global q_table
    q_table[state, action] += lr * (reward + gamma * q_table[next_state, next_action] * (1 - done) - q_table[state, action])

# %%
running_reward = []
for episode in range(1, 1 + max_episodes):
    state = env.reset()
    action = choose_action(state)
    done = False  
    episode_reward = 0
    while not done:
        next_state, reward, done, _ = env.step(action)
        next_action = choose_action(next_state)
        update_table(state, action, reward, done, next_state, next_action)
        
        episode_reward += reward

        state = next_state
        action = next_action
            
    epsilon  = epsilon - decay_rate if epsilon - decay_rate > min_epsilon else min_epsilon
    
    if episode == 1:
        running_reward.append(episode_reward)
    else:
        running_reward.append(0.99 * running_reward[-1] + 0.01 * episode_reward)
    if episode % print_interval == 0:
        print(f"Ep:{episode}| "
              f"Ep_reward:{episode_reward}| "
              f"Running_reward:{running_reward[-1]:.3f}| "
             f"Epsilon:{epsilon:.3f}| ")
# Out:
# Ep:50| Ep_reward:-776| Running_reward:-807.332| Epsilon:0.950|
# Ep:100| Ep_reward:-740| Running_reward:-773.517| Epsilon:0.900|
# Ep:150| Ep_reward:-512| Running_reward:-714.257| Epsilon:0.850|
# Ep:200| Ep_reward:-605| Running_reward:-666.135| Epsilon:0.800|
# Ep:250| Ep_reward:-659| Running_reward:-538.144| Epsilon:0.750|
# Ep:300| Ep_reward:-410| Running_reward:-431.797| Epsilon:0.700|
# Ep:350| Ep_reward:-185| Running_reward:-335.785| Epsilon:0.650|
# Ep:400| Ep_reward:-94| Running_reward:-250.846| Epsilon:0.600|
# Ep:450| Ep_reward:-8| Running_reward:-182.161| Epsilon:0.550|
# Ep:500| Ep_reward:-44| Running_reward:-135.863| Epsilon:0.500|
# Ep:550| Ep_reward:6| Running_reward:-98.472| Epsilon:0.450|
# Ep:600| Ep_reward:-29| Running_reward:-72.028| Epsilon:0.400|
# Ep:650| Ep_reward:-61| Running_reward:-54.939| Epsilon:0.350|
# Ep:700| Ep_reward:0| Running_reward:-42.561| Epsilon:0.300|
# Ep:750| Ep_reward:-20| Running_reward:-28.820| Epsilon:0.250|
# Ep:800| Ep_reward:-44| Running_reward:-20.086| Epsilon:0.200|
# Ep:850| Ep_reward:12| Running_reward:-13.441| Epsilon:0.150|
# Ep:900| Ep_reward:7| Running_reward:-7.574| Epsilon:0.100|
# Ep:950| Ep_reward:3| Running_reward:-2.773| Epsilon:0.050|
# Ep:1000| Ep_reward:10| Running_reward:0.555| Epsilon:0.010|
# Ep:1050| Ep_reward:9| Running_reward:3.236| Epsilon:0.010|
# Ep:1100| Ep_reward:7| Running_reward:4.609| Epsilon:0.010|
# Ep:1150| Ep_reward:9| Running_reward:5.634| Epsilon:0.010|
# Ep:1200| Ep_reward:10| Running_reward:6.566| Epsilon:0.010|
# Ep:1250| Ep_reward:9| Running_reward:7.066| Epsilon:0.010|
# Ep:1300| Ep_reward:12| Running_reward:7.447| Epsilon:0.010|
# Ep:1350| Ep_reward:6| Running_reward:7.508| Epsilon:0.010|
# Ep:1400| Ep_reward:6| Running_reward:7.496| Epsilon:0.010|
# Ep:1450| Ep_reward:14| Running_reward:7.595| Epsilon:0.010|
# Ep:1500| Ep_reward:7| Running_reward:7.426| Epsilon:0.010|
# Ep:1550| Ep_reward:3| Running_reward:7.564| Epsilon:0.010|
# Ep:1600| Ep_reward:8| Running_reward:7.047| Epsilon:0.010|
# Ep:1650| Ep_reward:11| Running_reward:7.257| Epsilon:0.010|
# Ep:1700| Ep_reward:5| Running_reward:7.412| Epsilon:0.010|
# Ep:1750| Ep_reward:8| Running_reward:7.232| Epsilon:0.010|
# Ep:1800| Ep_reward:3| Running_reward:6.952| Epsilon:0.010|
# Ep:1850| Ep_reward:10| Running_reward:6.858| Epsilon:0.010|
# Ep:1900| Ep_reward:12| Running_reward:7.213| Epsilon:0.010|
# Ep:1950| Ep_reward:3| Running_reward:7.245| Epsilon:0.010|
# Ep:2000| Ep_reward:9| Running_reward:7.297| Epsilon:0.010|
# Ep:2050| Ep_reward:8| Running_reward:7.205| Epsilon:0.010|
# Ep:2100| Ep_reward:-2| Running_reward:7.244| Epsilon:0.010|
# Ep:2150| Ep_reward:9| Running_reward:7.506| Epsilon:0.010|
# Ep:2200| Ep_reward:8| Running_reward:7.137| Epsilon:0.010|
# Ep:2250| Ep_reward:9| Running_reward:7.506| Epsilon:0.010|
# Ep:2300| Ep_reward:8| Running_reward:7.708| Epsilon:0.010|
# Ep:2350| Ep_reward:7| Running_reward:7.802| Epsilon:0.010|
# Ep:2400| Ep_reward:11| Running_reward:7.556| Epsilon:0.010|
# Ep:2450| Ep_reward:7| Running_reward:7.429| Epsilon:0.010|
# Ep:2500| Ep_reward:-6| Running_reward:7.171| Epsilon:0.010|

# %%
plt.figure()
plt.style.use("ggplot")
plt.plot(np.arange(max_episodes), running_reward)
plt.title("Running_reward")
# Out:
# Text(0.5, 1.0, 'Running_reward')

# %%
for episode in range(1, 1 + test_episodes):
    state = env.reset()
    done = False  
    episode_reward = 0
    while not done:
        action = choose_action(state)
        next_state, reward, done, _ = env.step(action)
        env.render()
        episode_reward += reward
        state = next_state

    print(f"Ep:{episode}| "
          f"Ep_reward:{episode_reward}| ")
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:1| Ep_reward:12|
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:2| Ep_reward:4|

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
env_name = "Taxi-v2"
epsilon = 1
decay_rate = 0.001
min_epsilon = 0.01
max_episodes = 2500
print_interval = 50
test_episodes = 2
lr = 0.4
gamma = 0.99
lam = 0.9

# %%
env = gym.make(env_name)
n_states = env.observation_space.n
n_actions = env.action_space.n
print(f"Number of states: {n_states}\n"
      f"Number of actions: {n_actions}")
# Out:
# Number of states: 500
# Number of actions: 6

# %%
q_table = e_table = np.zeros((n_states, n_actions))

# %%
def choose_action(state):
    global q_table
    if epsilon > np.random.uniform():
        action = env.action_space.sample()
    else:
        action = np.argmax(q_table[state, :])
    return action

# %%
# def update_table(state, action, reward, done, next_state):
#     global q_table
#     q_table[state, action] += lr * (reward + gamma * np.max(q_table[next_state, :]) * (1 - done) - q_table[state, action])

# %%
running_reward = []
for episode in range(1, 1 + max_episodes):
    state = env.reset()
    done = False  
    episode_reward = 0
    while not done:
        action = choose_action(state)
        next_state, reward, done, _ = env.step(action)
        next_action = choose_action(next_state)
        
        optimal_next_action = np.argmax(q_table[next_state, :])
        delta = reward + gamma * q_table[next_state, optimal_next_action] * (1 - done) - q_table[state, action]
        e_table[state, action] += 1
        
        q_table = q_table + lr * delta * e_table
        
        if next_action == optimal_next_action:
            e_table = gamma * lam * e_table
        else:
            e_table = np.zeros((n_states, n_actions))                
        
#         update_table(state, action, reward, done, next_state)
        
        episode_reward += reward

        state = next_state
        action = next_action
            
    epsilon  = epsilon - decay_rate if epsilon - decay_rate > min_epsilon else min_epsilon
    
    if episode == 1:
        running_reward.append(episode_reward)
    else:
        running_reward.append(0.99 * running_reward[-1] + 0.01 * episode_reward)
    if episode % print_interval == 0:
        print(f"Ep:{episode}| "
              f"Ep_reward:{episode_reward}| "
              f"Running_reward:{running_reward[-1]:.3f}| "
             f"Epsilon:{epsilon:.3f}| ")
# Out:
# Ep:50| Ep_reward:-830| Running_reward:-679.437| Epsilon:0.950|
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in add
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in multiply
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   if sys.path[0] == '':
# Ep:100| Ep_reward:-713| Running_reward:-704.379| Epsilon:0.900|
# Ep:150| Ep_reward:-623| Running_reward:-703.518| Epsilon:0.850|
# Ep:200| Ep_reward:-686| Running_reward:-690.401| Epsilon:0.800|
# Ep:250| Ep_reward:-641| Running_reward:-670.836| Epsilon:0.750|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-62beccfb6cc4> in <module>
#      13         e_table[state, action] += 1
#      14
# ---> 15         q_table = q_table + lr * delta * e_table
#      16
#      17         if next_action == optimal_next_action:
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.style.use("ggplot")
plt.plot(np.arange(max_episodes), running_reward)
plt.title("Running_reward")

# %%
for episode in range(1, 1 + test_episodes):
    state = env.reset()
    done = False  
    episode_reward = 0
    while not done:
        action = choose_action(state)
        next_state, reward, done, _ = env.step(action)
        env.render()
        episode_reward += reward
        state = next_state

    print(f"Ep:{episode}| "
          f"Ep_reward:{episode_reward}| ")
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:1| Ep_reward:12|
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Ep:2| Ep_reward:4|
